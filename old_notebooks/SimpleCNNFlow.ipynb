# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn

import torchvision
import torchvision.transforms as transforms
from torch.autograd import Variable
import time
import numpy as np
use_cuda = True
batch_size = 500

# %%
from _invertible import *

# %%
unorm = UnNormalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))

# %%
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=2),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
])

# %%
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=2),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=False, transform=transform_test)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)
testloader = torch.utils.data.DataLoader(testset, batch_size=1000, shuffle=False, num_workers=2)
# Out:
# Files already downloaded and verified

# %%
from _invertible import ConvAutoencoder, Flatten, Unflatten, Crop

encoder = nn.Sequential(
  nn.Conv2d(3, 64, kernel_size=3, stride=2, padding=1),
  nn.BatchNorm2d(64),
  nn.ReLU(),
  nn.Conv2d(64, 256, kernel_size=3, stride=2, padding=1),
  nn.BatchNorm2d(256),
  nn.ReLU(),
  nn.Conv2d(256, 512, kernel_size=3, stride=2, padding=1),
  nn.BatchNorm2d(512),
  nn.ReLU(),
  nn.Conv2d(512, 128, kernel_size=3, stride=2, padding=1),
)

decoder = nn.Sequential(
  nn.ConvTranspose2d(128, 512, kernel_size=4, stride=2, padding=1),
  nn.BatchNorm2d(512),
  nn.ReLU(),
  nn.ConvTranspose2d(512, 256, kernel_size=4, stride=2, padding=1),
  nn.BatchNorm2d(256),
  nn.ReLU(),
  nn.ConvTranspose2d(256, 64, kernel_size=4, stride=2, padding=1),
  nn.BatchNorm2d(64),
  nn.ReLU(),
  nn.ConvTranspose2d(64, 3, kernel_size=4, stride=2, padding=1),
  nn.Sigmoid(),
)

# %%
# Out:
# torch.Size([500, 3, 32, 32])

# %%
model = ConvAutoencoder(encoder, decoder).cuda()
opt = optim.Adam(model.parameters(), lr=2e-3)
epochs = 150
scheduler = optim.lr_scheduler.StepLR(opt, epochs // 3, gamma=0.1, last_epoch=-1)
criterion = torch.nn.MSELoss()

# %%
for epoch in range(epochs):

  print('epoch %s' % epoch)
  t = time.time()
  model.train()
  train_loss = 0
  for i, (img, label) in enumerate(trainloader):
    img = img.cuda()
    z = model.forward(img)
    x_hat = model.reverse(z)
    loss = criterion(img[:,:,2:-2,2:-2], x_hat[:,:,2:-2,2:-2])
    train_loss += loss
    
    opt.zero_grad()
    loss.backward()
    opt.step()
    
    if (i+1) % 10 == 0:
      print('{:.4f},'.format(train_loss/10.),end='',flush=True)
      train_loss = 0
  print('')
  print('training epoch took {:.4f}'.format(time.time() - t))

  # test loop
  # --------------------------------------------------------------------------
  model.eval()
  with torch.no_grad():
    total_loss = 0
    for i, (img, label) in enumerate(testloader): 
      img = img.cuda() 
      z = model.forward(img)
      x_hat = model.reverse(z)
      total_loss += criterion(img[:,:,2:-2,2:-2], x_hat[:,:,2:-2,2:-2])
      
    print('avg test loss: {}'.format(total_loss / i))
  scheduler.step()
# Out:
# epoch 0
# 0.0033,0.0018,0.0014,0.0013,0.0012,0.0011,0.0010,0.0011,0.0010,0.0010,
# training epoch took 10.1974
# avg test loss: 0.00117663259152323
# epoch 1
# 0.0010,0.0010,0.0011,0.0010,0.0010,0.0010,0.0010,0.0011,0.0011,0.0010,
# training epoch took 10.2892
# avg test loss: 0.0011648554354906082
# epoch 2
# 0.0011,0.0010,0.0010,0.0010,0.0010,0.0011,0.0010,0.0011,0.0011,0.0010,
# training epoch took 10.3721
# avg test loss: 0.0011365688405930996
# epoch 3
# 0.0010,0.0010,0.0011,0.0010,0.0011,0.0011,0.0011,0.0010,0.0011,0.0010,
# training epoch took 10.3816
# avg test loss: 0.0010812514228746295
# epoch 4
# 0.0010,0.0010,0.0010,0.0010,0.0010,0.0011,0.0010,0.0010,0.0010,0.0010,
# training epoch took 10.3955
# avg test loss: 0.001129408716224134
# epoch 5
# 0.0011,0.0010,0.0010,0.0010,0.0010,0.0010,0.0010,0.0011,0.0011,0.0010,
# training epoch took 10.3952
# avg test loss: 0.0011176277184858918
# epoch 6
# 0.0011,0.0010,0.0010,0.0010,0.0010,0.0010,0.0010,0.0010,0.0010,0.0010,
# training epoch took 10.4964
# avg test loss: 0.0012090607779100537
# epoch 7
# 0.0010,0.0010,0.0010,0.0010,0.0010,0.0010,0.0010,0.0010,0.0011,0.0011,
# training epoch took 10.5113
# avg test loss: 0.0012155564036220312
# epoch 8
# 0.0011,0.0012,0.0011,0.0011,0.0011,0.0010,0.0010,0.0010,0.0010,0.0010,
# training epoch took 10.5435
# avg test loss: 0.0010892502032220364
# epoch 9
# 0.0010,0.0010,0.0010,0.0010,0.0010,0.0010,0.0011,0.0011,0.0010,0.0010,
# training epoch took 10.5474
# avg test loss: 0.0010686337482184172
# epoch 10
# 0.0010,0.0010,0.0010,0.0010,0.0010,0.0010,0.0010,0.0009,0.0010,0.0010,
# training epoch took 10.5695
# avg test loss: 0.0010701010469347239
# epoch 11
# 0.0010,0.0010,0.0010,0.0010,0.0009,0.0010,0.0009,0.0010,0.0010,0.0010,
# training epoch took 10.6867
# avg test loss: 0.0010715143289417028
# epoch 12
# 0.0010,0.0010,0.0010,0.0010,0.0010,0.0010,0.0009,0.0010,0.0010,0.0009,
# training epoch took 10.6883
# avg test loss: 0.0010163438273593783
# epoch 13
# 0.0009,0.0010,0.0010,0.0010,0.0010,0.0010,0.0010,0.0010,0.0010,0.0010,
# training epoch took 10.7186
# avg test loss: 0.0010601606918498874
# epoch 14
# 0.0009,0.0009,0.0010,0.0010,0.0009,0.0010,0.0010,0.0010,0.0009,0.0010,
# training epoch took 10.7798
# avg test loss: 0.0011007296852767467
# epoch 15
# 0.0009,0.0009,0.0009,0.0010,0.0010,0.0010,0.0011,0.0010,0.0010,0.0010,
# training epoch took 10.9129
# avg test loss: 0.0011045769788324833
# epoch 16
# 0.0011,0.0010,0.0010,0.0010,0.0010,0.0011,0.0010,0.0010,0.0010,0.0010,
# training epoch took 10.8224
# avg test loss: 0.0010905590606853366
# epoch 17
# 0.0009,0.0010,0.0009,0.0009,0.0010,0.0010,0.0010,0.0010,0.0010,0.0010,
# training epoch took 10.8235
# avg test loss: 0.0011985283344984055
# epoch 18
# 0.0010,0.0010,0.0010,0.0011,0.0010,0.0009,0.0010,0.0010,0.0009,0.0009,
# training epoch took 10.9149
# avg test loss: 0.0010147674474865198
# epoch 19
# 0.0009,0.0010,0.0010,0.0010,0.0010,0.0009,0.0010,0.0010,0.0010,0.0009,
# training epoch took 10.8168
# avg test loss: 0.0010360487503930926
# epoch 20
# 0.0010,0.0010,0.0009,0.0010,0.0010,0.0009,0.0009,0.0010,0.0009,0.0009,
# training epoch took 10.8345
# avg test loss: 0.001153690624050796
# epoch 21
# 0.0010,0.0010,0.0009,0.0010,0.0009,0.0009,0.0009,0.0010,0.0009,0.0009,
# training epoch took 10.8238
# avg test loss: 0.0009894914692267776
# epoch 22
# 0.0009,0.0009,0.0009,0.0009,0.0009,0.0009,0.0009,0.0010,0.0010,0.0009,
# training epoch took 10.8751
# avg test loss: 0.0010017255553975701
# epoch 23
# 0.0009,0.0009,0.0009,0.0009,0.0009,0.0010,0.0009,0.0010,0.0010,0.0009,
# training epoch took 11.1640
# avg test loss: 0.0010408095549792051
# epoch 24
# 0.0010,0.0010,0.0010,0.0009,0.0009,0.0009,0.0010,0.0010,0.0011,0.0010,
# training epoch took 10.8908
# avg test loss: 0.0010908003896474838
# epoch 25
# 0.0010,0.0010,0.0009,0.0010,0.0009,0.0009,0.0009,0.0009,0.0009,0.0009,
# training epoch took 10.8979
# avg test loss: 0.0011525793233886361
# epoch 26
# 0.0010,0.0009,0.0009,0.0009,0.0009,0.0009,0.0009,0.0009,0.0009,0.0009,
# training epoch took 10.8464
# avg test loss: 0.0010665159206837416
# epoch 27
# 0.0009,0.0009,0.0009,0.0009,0.0010,0.0009,0.0009,0.0009,0.0010,0.0009,
# training epoch took 10.8730
# avg test loss: 0.001124286325648427
# epoch 28
# 0.0009,0.0009,0.0009,0.0009,0.0009,0.0009,0.0010,0.0010,0.0010,0.0010,
# training epoch took 10.9524
# avg test loss: 0.0010224186116829515
# epoch 29
# 0.0009,0.0009,0.0010,0.0010,0.0009,0.0009,0.0009,0.0009,0.0009,0.0009,
# training epoch took 10.8753
# avg test loss: 0.0011580768041312695
# epoch 30
# 0.0010,0.0009,0.0009,0.0009,0.0009,0.0009,0.0009,0.0010,0.0009,0.0009,
# training epoch took 10.9549
# avg test loss: 0.001002477714791894
# epoch 31
# 0.0009,0.0009,0.0010,0.0010,0.0009,0.0010,0.0009,0.0009,0.0009,0.0009,
# training epoch took 10.8269
# avg test loss: 0.0010286389151588082
# epoch 32
# 0.0010,0.0009,0.0009,0.0009,0.0009,0.0009,0.0009,0.0009,0.0009,0.0009,
# training epoch took 10.8423
# avg test loss: 0.0012987793888896704
# epoch 33
# 0.0009,0.0009,0.0009,0.0009,0.0009,0.0009,0.0009,0.0009,0.0010,0.0010,
# training epoch took 10.8084
# avg test loss: 0.0010558428475633264
# epoch 34
# 0.0009,0.0009,0.0009,0.0010,0.0009,0.0009,0.0009,0.0009,0.0009,0.0009,
# training epoch took 10.8315
# avg test loss: 0.001031760941259563
# epoch 35
# 0.0009,0.0009,0.0009,0.0009,0.0009,0.0009,0.0009,0.0010,0.0010,0.0009,
# training epoch took 10.9078
# avg test loss: 0.0010807584039866924
# epoch 36
# 0.0009,0.0009,0.0009,0.0009,0.0009,0.0009,0.0009,0.0009,0.0009,0.0008,
# training epoch took 10.7801
# avg test loss: 0.0009426141623407602
# epoch 37
# 0.0009,0.0009,0.0009,0.0010,0.0010,0.0010,0.0009,0.0010,0.0010,0.0009,
# training epoch took 10.9063
# avg test loss: 0.0009485247428528965
# epoch 38
# 0.0009,0.0009,0.0009,0.0009,0.0009,0.0009,0.0009,0.0009,0.0010,0.0009,
# training epoch took 10.7292
# avg test loss: 0.0009575265576131642
# epoch 39
# 0.0009,0.0009,0.0009,0.0009,0.0009,0.0009,0.0009,0.0009,0.0009,0.0009,
# training epoch took 10.9522
# avg test loss: 0.0009793220087885857
# epoch 40
# 0.0010,0.0009,0.0009,0.0009,0.0008,0.0008,0.0009,0.0009,0.0009,0.0009,
# training epoch took 10.7474
# avg test loss: 0.0009809387847781181
# epoch 41
# 0.0009,0.0009,0.0009,0.0009,0.0009,0.0009,0.0009,0.0010,0.0010,0.0009,
# training epoch took 10.9813
# avg test loss: 0.000948556000366807
# epoch 42
# 0.0009,0.0009,0.0009,0.0009,0.0009,0.0009,0.0009,0.0008,0.0009,0.0008,
# training epoch took 10.8877
# avg test loss: 0.0009292960166931152
# epoch 43
# 0.0009,0.0009,0.0010,0.0009,0.0009,0.0009,0.0009,0.0009,0.0009,0.0008,
# training epoch took 10.9026
# avg test loss: 0.0009749900200404227
# epoch 44
# 0.0009,0.0009,0.0009,0.0010,0.0010,0.0009,0.0009,0.0009,0.0009,0.0009,
# training epoch took 10.8457
# avg test loss: 0.0009843582520261407
# epoch 45
# 0.0009,0.0009,0.0010,0.0009,0.0009,0.0009,0.0009,0.0010,0.0009,0.0008,
# training epoch took 10.8384
# avg test loss: 0.0009531405521556735
# epoch 46
# 0.0009,0.0009,0.0009,0.0009,0.0009,0.0010,0.0009,0.0009,0.0009,0.0009,
# training epoch took 10.9168
# avg test loss: 0.0010283658048138022
# epoch 47
# 0.0009,0.0009,0.0009,0.0009,0.0009,0.0009,0.0009,0.0009,0.0009,0.0009,
# training epoch took 11.0453
# avg test loss: 0.0010042550275102258
# epoch 48
# 0.0009,0.0008,0.0009,0.0009,0.0009,0.0008,0.0009,0.0009,0.0009,0.0009,
# training epoch took 10.7881
# avg test loss: 0.0010023763170465827
# epoch 49
# 0.0009,0.0009,0.0010,0.0009,0.0009,0.0009,0.0009,0.0009,0.0009,0.0009,
# training epoch took 10.8015
# avg test loss: 0.0012107009533792734
# epoch 50
# 0.0008,0.0008,0.0008,0.0008,0.0008,0.0008,0.0008,0.0008,0.0008,0.0008,
# training epoch took 10.8430
# avg test loss: 0.0008231828105635941
# epoch 51
# 0.0008,0.0008,0.0008,0.0008,0.0008,0.0008,0.0008,0.0008,0.0008,0.0008,
# training epoch took 10.8094
# avg test loss: 0.0008187945932149887
# epoch 52
# 0.0008,0.0008,0.0008,0.0008,0.0008,0.0008,0.0008,0.0008,0.0008,0.0008,
# training epoch took 10.7836
# avg test loss: 0.0008164115133695304
# epoch 53
# 0.0008,0.0008,0.0008,0.0008,0.0008,0.0008,0.0008,0.0008,0.0008,0.0008,
# training epoch took 10.7204
# avg test loss: 0.0008247756632044911
# epoch 54
# 0.0008,0.0008,0.0008,0.0008,0.0008,0.0008,0.0008,0.0007,0.0008,0.0008,
# training epoch took 10.7708
# avg test loss: 0.0008169421926140785
# epoch 55
# 0.0007,0.0008,0.0008,0.0008,0.0008,0.0008,0.0008,0.0007,0.0007,0.0008,
# training epoch took 11.0236
# avg test loss: 0.0008107672911137342
# epoch 56
# 0.0008,0.0008,0.0007,0.0008,0.0008,0.0008,0.0007,0.0008,0.0007,0.0008,
# training epoch took 10.8441
# avg test loss: 0.0008181548328138888
# epoch 57
# 0.0008,0.0008,0.0008,0.0008,0.0007,0.0007,0.0008,0.0008,0.0008,0.0008,
# training epoch took 10.9691
# avg test loss: 0.0008146534091793001
# epoch 58
# 0.0008,0.0007,0.0008,0.0007,0.0008,0.0008,0.0008,0.0008,0.0007,0.0007,
# training epoch took 10.9873
# avg test loss: 0.0008086220477707684
# epoch 59
# 0.0008,0.0008,0.0008,0.0008,0.0008,0.0008,0.0008,0.0008,0.0008,0.0007,
# training epoch took 10.9005
# avg test loss: 0.0008111292263492942
# epoch 60
# 0.0008,0.0008,0.0008,0.0008,0.0007,0.0008,0.0008,0.0008,0.0008,0.0007,
# training epoch took 10.7960
# avg test loss: 0.0008114197407849133
# epoch 61
# 0.0008,0.0008,0.0007,0.0008,0.0008,0.0008,0.0008,0.0008,0.0007,0.0008,
# training epoch took 10.6763
# avg test loss: 0.0008086998132057488
# epoch 62
# 0.0007,0.0008,0.0008,0.0008,0.0008,0.0007,0.0008,0.0007,0.0008,0.0008,
# training epoch took 10.8645
# avg test loss: 0.0008151316433213651
# epoch 63
# 0.0008,0.0008,0.0008,0.0008,0.0008,0.0008,0.0008,0.0008,0.0008,0.0008,
# training epoch took 10.8119
# avg test loss: 0.0008132850052788854
# epoch 64
# 0.0008,0.0007,0.0008,0.0008,0.0007,0.0008,0.0007,0.0008,0.0008,0.0008,
# training epoch took 10.9307
# avg test loss: 0.0008113684016279876
# epoch 65
# 0.0008,0.0008,0.0008,0.0007,0.0007,0.0008,0.0008,0.0007,0.0007,0.0007,
# training epoch took 10.7833
# avg test loss: 0.0008115595555864275
# epoch 66
# 0.0008,0.0008,0.0007,0.0008,0.0007,0.0008,0.0007,0.0008,0.0008,0.0007,
# training epoch took 10.8674
# avg test loss: 0.0008129936177283525
# epoch 67
# 0.0008,0.0007,0.0008,0.0008,0.0007,0.0008,0.0008,0.0007,0.0008,0.0008,
# training epoch took 11.1861
# avg test loss: 0.000806041294708848
# epoch 68
# 0.0008,0.0008,0.0007,0.0007,0.0007,0.0008,0.0007,0.0008,0.0007,0.0007,
# training epoch took 10.9967
# avg test loss: 0.0008082202402874827
# epoch 69
# 0.0008,0.0008,0.0008,0.0007,0.0007,0.0007,0.0008,0.0008,0.0007,0.0007,
# training epoch took 10.8666
# avg test loss: 0.0008068023016676307
# epoch 70
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0008,0.0007,0.0007,0.0008,
# training epoch took 10.8658
# avg test loss: 0.0008063784916885197
# epoch 71
# 0.0007,0.0008,0.0007,0.0008,0.0008,0.0007,0.0008,0.0008,0.0007,0.0007,
# training epoch took 10.9048
# avg test loss: 0.000804352865088731
# epoch 72
# 0.0007,0.0008,0.0007,0.0007,0.0008,0.0008,0.0008,0.0008,0.0008,0.0008,
# training epoch took 10.7464
# avg test loss: 0.0008046249859035015
# epoch 73
# 0.0007,0.0007,0.0007,0.0007,0.0008,0.0007,0.0007,0.0008,0.0008,0.0007,
# training epoch took 10.9702
# avg test loss: 0.0008039645617827773
# epoch 74
# 0.0008,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0008,0.0007,0.0007,
# training epoch took 10.8989
# avg test loss: 0.0008082118583843112
# epoch 75
# 0.0008,0.0007,0.0007,0.0007,0.0008,0.0008,0.0007,0.0007,0.0008,0.0007,
# training epoch took 10.9575
# avg test loss: 0.0008184575708582997
# epoch 76
# 0.0007,0.0007,0.0008,0.0007,0.0007,0.0007,0.0008,0.0007,0.0007,0.0007,
# training epoch took 10.8344
# avg test loss: 0.0008062320994213223
# epoch 77
# 0.0007,0.0008,0.0008,0.0008,0.0007,0.0007,0.0007,0.0008,0.0008,0.0008,
# training epoch took 10.9608
# avg test loss: 0.0008136977558024228
# epoch 78
# 0.0007,0.0007,0.0008,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.7745
# avg test loss: 0.0008000927628017962
# epoch 79
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0008,0.0007,0.0008,0.0007,
# training epoch took 10.9178
# avg test loss: 0.0007999189547263086
# epoch 80
# 0.0007,0.0008,0.0007,0.0007,0.0008,0.0007,0.0007,0.0007,0.0008,0.0007,
# training epoch took 10.7235
# avg test loss: 0.0008007392170839012
# epoch 81
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0008,
# training epoch took 10.8252
# avg test loss: 0.0008078904938884079
# epoch 82
# 0.0007,0.0007,0.0008,0.0007,0.0008,0.0007,0.0007,0.0007,0.0007,0.0008,
# training epoch took 10.8163
# avg test loss: 0.0008007472497411072
# epoch 83
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0008,0.0007,0.0008,0.0008,0.0007,
# training epoch took 10.8769
# avg test loss: 0.0008006911375559866
# epoch 84
# 0.0007,0.0007,0.0007,0.0007,0.0008,0.0008,0.0007,0.0008,0.0007,0.0007,
# training epoch took 10.8409
# avg test loss: 0.000805811258032918
# epoch 85
# 0.0007,0.0007,0.0007,0.0007,0.0008,0.0008,0.0007,0.0008,0.0008,0.0007,
# training epoch took 10.8541
# avg test loss: 0.0007980978698469698
# epoch 86
# 0.0008,0.0007,0.0007,0.0007,0.0007,0.0007,0.0008,0.0007,0.0007,0.0007,
# training epoch took 10.8314
# avg test loss: 0.0008025959832593799
# epoch 87
# 0.0007,0.0007,0.0008,0.0007,0.0007,0.0007,0.0008,0.0008,0.0007,0.0007,
# training epoch took 10.8540
# avg test loss: 0.0008000009111128747
# epoch 88
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0008,
# training epoch took 10.7887
# avg test loss: 0.0008011016179807484
# epoch 89
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0008,0.0008,0.0007,0.0008,
# training epoch took 10.9867
# avg test loss: 0.0008112575742416084
# epoch 90
# 0.0007,0.0007,0.0008,0.0008,0.0008,0.0007,0.0008,0.0008,0.0008,0.0008,
# training epoch took 10.8130
# avg test loss: 0.0008016421343199909
# epoch 91
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.9441
# avg test loss: 0.0007949043065309525
# epoch 92
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.9152
# avg test loss: 0.0007944983663037419
# epoch 93
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0008,0.0007,0.0007,
# training epoch took 10.8995
# avg test loss: 0.0007982541574165225
# epoch 94
# 0.0007,0.0007,0.0008,0.0008,0.0007,0.0008,0.0007,0.0007,0.0007,0.0007,
# training epoch took 11.0794
# avg test loss: 0.0007941110525280237
# epoch 95
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0008,0.0007,0.0007,
# training epoch took 10.8561
# avg test loss: 0.0007955105393193662
# epoch 96
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.7316
# avg test loss: 0.0007939827628433704
# epoch 97
# 0.0007,0.0008,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.7372
# avg test loss: 0.0007928802515380085
# epoch 98
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0008,0.0007,0.0007,0.0007,
# training epoch took 10.8733
# avg test loss: 0.0007960892980918288
# epoch 99
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0008,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.9170
# avg test loss: 0.0008010639576241374
# epoch 100
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.9397
# avg test loss: 0.000781319395173341
# epoch 101
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.8579
# avg test loss: 0.0007810031529515982
# epoch 102
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.7891
# avg test loss: 0.0007801242172718048
# epoch 103
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.8087
# avg test loss: 0.0007802251493558288
# epoch 104
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.9240
# avg test loss: 0.0007800246821716428
# epoch 105
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.6904
# avg test loss: 0.0007799221784807742
# epoch 106
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.8701
# avg test loss: 0.0007795595447532833
# epoch 107
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.9017
# avg test loss: 0.0007809155504219234
# epoch 108
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.8553
# avg test loss: 0.0007796900463290513
# epoch 109
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.7839
# avg test loss: 0.0007802650798112154
# epoch 110
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.8885
# avg test loss: 0.0007792921387590468
# epoch 111
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.9855
# avg test loss: 0.0007803415064699948
# epoch 112
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.8775
# avg test loss: 0.0007791706011630595
# epoch 113
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.7842
# avg test loss: 0.0007788720540702343
# epoch 114
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 11.0422
# avg test loss: 0.0007800732273608446
# epoch 115
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.8827
# avg test loss: 0.0007787280483171344
# epoch 116
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.7781
# avg test loss: 0.0007788842194713652
# epoch 117
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.9743
# avg test loss: 0.0007787322974763811
# epoch 118
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 11.0882
# avg test loss: 0.0007799977902323008
# epoch 119
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.8816
# avg test loss: 0.0007788416696712375
# epoch 120
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.8226
# avg test loss: 0.0007781696622259915
# epoch 121
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.8963
# avg test loss: 0.0007787853828631341
# epoch 122
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.9375
# avg test loss: 0.000778541958425194
# epoch 123
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.8954
# avg test loss: 0.00077862199395895
# epoch 124
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.7437
# avg test loss: 0.0007792929536662996
# epoch 125
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 11.1569
# avg test loss: 0.0007783373002894223
# epoch 126
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.6761
# avg test loss: 0.0007786029018461704
# epoch 127
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.7993
# avg test loss: 0.0007777094142511487
# epoch 128
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 11.0620
# avg test loss: 0.0007787452195771039
# epoch 129
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.9528
# avg test loss: 0.0007783403270877898
# epoch 130
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.8345
# avg test loss: 0.000778745103161782
# epoch 131
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.9394
# avg test loss: 0.0007781924796290696
# epoch 132
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.8346
# avg test loss: 0.0007799521554261446
# epoch 133
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.9126
# avg test loss: 0.0007777796126902103
# epoch 134
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.9007
# avg test loss: 0.0007777910795994103
# epoch 135
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.9191
# avg test loss: 0.0007780694868415594
# epoch 136
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.9962
# avg test loss: 0.0007783508044667542
# epoch 137
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.9312
# avg test loss: 0.0007776206475682557
# epoch 138
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.7413
# avg test loss: 0.0007778384606353939
# epoch 139
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.7861
# avg test loss: 0.0007780886953696609
# epoch 140
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 11.0675
# avg test loss: 0.0007799936574883759
# epoch 141
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 11.0355
# avg test loss: 0.0007773124380037189
# epoch 142
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.8085
# avg test loss: 0.0007775684935040772
# epoch 143
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.9225
# avg test loss: 0.0007777231512591243
# epoch 144
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.9279
# avg test loss: 0.0007790208328515291
# epoch 145
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.7805
# avg test loss: 0.0007770907832309604
# epoch 146
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.9094
# avg test loss: 0.0007778972503729165
# epoch 147
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 11.0116
# avg test loss: 0.0007773420074954629
# epoch 148
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.8343
# avg test loss: 0.0007771980599500239
# epoch 149
# 0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,0.0007,
# training epoch took 10.7897
# avg test loss: 0.0007785988273099065

# %%
x = next(iter(testloader))

# %%
z = model.forward(x[0].cuda())
x_hat = model.reverse(z)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import torchvision.utils as tutils
def show(img, w=12, h=4):
  if isinstance(img, torch.Tensor):
    img = img.cpu().detach()
  npimg = img.numpy().transpose(1,2,0)
  fig, ax = plt.subplots(figsize=(w, h))
  print(npimg.shape)
  ax.imshow(npimg)
  plt.tight_layout()

# %%
im = x[0]

# %%
show(tutils.make_grid((im[:16,:,2:-2,2:-2])))
# Out:
# (62, 242, 3)

# %%
z = model.forward(x[0].cuda())
x_hat = model.reverse(z * 1.5)

# %%
show(tutils.make_grid((x_hat[:16,:,2:-2,2:-2].cpu())))
# Out:
# (62, 242, 3)

# %%
z.shape
# Out:
# torch.Size([1000, 128, 2, 2])

# %%
m = torch.randn(1024, 1024)

# %%
# %%timeit
m.matmul(m)
# Out:
# 2.11 ms ± 4.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit
torch.inverse(m)
# Out:
# 7.94 ms ± 7.06 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit
torch.inverse(m).matmul(m)
# Out:
# 10.7 ms ± 6.71 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit
m*m
# Out:
# 81.7 µs ± 89 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %%timeit
torch.solve(m, m)
# Out:
# 8.04 ms ± 10.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

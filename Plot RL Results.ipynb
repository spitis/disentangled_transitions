# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('whitegrid')
# Out:
# /home/silviu/anaconda3/lib/python3.6/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
td3 = np.load('results/TD3_0.npy')
ddpg= np.load('results/DDPG_0.npy')

# %%
plt.plot(td3, label='td3')
plt.plot(ddpg, label='ddpg')
plt.legend()
plt.xlabel('2000s of steps')
plt.ylabel('Average Reward')
plt.title('Minimize Pairwise Distance Task')
# Out:
# Text(0.5, 1.0, 'Minimize Pairwise Distance Task')

# %%
td3 = np.load('results/TD3_1.npy')
ddpg= np.load('results/DDPG_1.npy')

# %%
plt.plot(td3, label='td3')
plt.plot(ddpg, label='ddpg')
plt.legend()
plt.xlabel('2000s of steps')
plt.ylabel('Average Reward')
plt.title('Maximize Pairwise Distance Task')
# Out:
# Text(0.5, 1.0, 'Maximize Pairwise Distance Task')

# %%
one = np.load('results/TD3_0_min_pairwise_None.npy')
two = np.load('results/TD3_0_min_pairwise_ground_truth.npy')

plt.plot(one, label='td3 - no coda')
plt.plot(two, label='td3 - GT coda')
plt.legend()
plt.xlabel('Thousands of steps')
plt.ylabel('Average Reward')
plt.title('Maximize Pairwise Distance Task')
# Out:
# Text(0.5, 1.0, 'Maximize Pairwise Distance Task')

# %%
one = np.load('results/TD3_1_min_pairwise_None.npy')
two = np.load('results/TD3_1_min_pairwise_ground_truth.npy')

plt.plot(one, label='td3 - no coda')
plt.plot(two, label='td3 - GT coda')
plt.legend()
plt.xlabel('Thousands of steps')
plt.ylabel('Average Reward')
plt.title('Maximize Pairwise Distance Task')
# Out:
# Text(0.5, 1.0, 'Maximize Pairwise Distance Task')

# %%
one = np.load('results/TD3_1_min_pairwise_None.npy')
two = np.load('results/TD3_1_min_pairwise_ground_truth.npy')
thr = np.load('results/TD3_1_min_pairwise_ground_truth_cool.npy')
fou = np.load('results/TD3_1_min_pairwise_ground_truth_cool2.npy')
fiv = np.load('results/TD3_1_min_pairwise_ground_truth_cool3.npy')

plt.plot(one, label='td3 - no coda')
plt.plot(two, label='td3 - GT coda')
plt.plot(thr)
plt.plot(fou)
plt.plot(fiv)
plt.legend()
plt.xlabel('Thousands of steps')
plt.ylabel('Average Reward')
plt.title('Maximize Pairwise Distance Task')
# Out:
# Text(0.5, 1.0, 'Maximize Pairwise Distance Task')

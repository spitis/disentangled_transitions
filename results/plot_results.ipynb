# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from scipy.ndimage.filters import gaussian_filter1d
sns.set_style('whitegrid')
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 12})

# %%
rewards = ['partial', 'sparse']
agents  = ['ground_truth', 'attn_mech', 'mmn', 'dyna', 'None']
labels  = ['CoDA (ground truth)', 'CoDA (learned transformer)', 'CoDA (learned mixture model)', 'Dyna (learned transformer)', 'Base Agent (TD3)']
colors  = ['#ff7f00','#e41a1c','#984ea3','#4daf4a','#377eb8','#ffff33','#a65628','#f781bf']
#colors  = ['#66c2a5','#fc8d62','#8da0cb','#e78ac3','#a6d854','#ffd92f','#e5c494','#b3b3b3']
#colors  = ['#1b9e77','#d95f02','#7570b3','#e7298a','#66a61e','#e6ab02','#a6761d','#666666']
COLOR   = dict(zip(agents, colors))
LABEL   = dict(zip(agents, labels))
Ns      = [1,2,3,4]
seeds   = [0, 1, 2]
M       = 350
LIMS    = [[(0.2, 0.8)]*4, [(0., 0.8)]*4]

# %%
def plot_result(reward, N, coda, ax = plt):
  
  # Load the result plots
  files = [f"TD3_place_{reward}_{N}_{coda}___{s}.npy" for s in seeds]
  plots = [np.load(file) for file in files]
  M     = np.min([len(p) for p in plots])
  plots = [p[:M] for p in plots]
  
  # plots the result plots
  c = COLOR[coda]
  [ax.plot(p, c=c, alpha=0.2) for p in plots]
  ax.plot(gaussian_filter1d(np.mean(plots, axis=0).copy(),sigma=10), c=c, linewidth=2)
  legend = ax.plot([], color=c, label=LABEL[coda])

def plot():
  
  fig, axes = plt.subplots(2, 4, False, False, figsize=(18,8))
  
  for i, row in enumerate(axes):
    for j, ax in enumerate(row):
      reward = rewards[i]
      N = Ns[j]
      for coda in agents:
        plot_result(reward, N, coda, ax = ax)
      if i==1 and j == 3:
        legend = ax.legend(loc='upper right', fontsize='large')
        for legobj in legend.legendHandles:
          legobj.set_linewidth(5)
      if i == 1:
        ax.set_xlabel('Thousands of steps')
      if j == 0:
        ax.set_ylabel('Average Reward')
      ax.set_title(f"{reward} reward, place {N} task")
      ax.set_xlim(0, M)
      ax.set_ylim(*LIMS[i][j])
  
  plt.tight_layout()
  plt.savefig('rl_results_plot.png', dpi=300)
  plt.show()

# %%
plot()

# %%
plots = [np.load(file) for file in files]
[plt.plot(p, label=f) for p,f in zip(plots, files)]
plt.legend(loc='lower right')
plt.xlabel('Thousands of steps')
plt.ylabel('Average Reward')
plt.title('Maximize Pairwise Distance Task')
plt.xlim(0, 1000)
plt.ylim(.4, .8)
# Out:
# (0.4, 0.8)

# %%
files = ['TD3_max_pairwise_None_1___0.npy',
         'TD3_max_pairwise_None_2___0.npy',
         'TD3_max_pairwise_None_4___0.npy',
         'TD3_max_pairwise_None_8___0.npy',
         'TD3_max_pairwise_None_16___0.npy']

# %%
plots = [np.load(file) for file in files]
[plt.plot(p, label=f) for p,f in zip(plots, files)]
plt.legend(loc='lower right')
plt.xlabel('Thousands of steps')
plt.ylabel('Average Reward')
plt.title('Maximize Pairwise Distance Task')
plt.xlim(0, 1000)
plt.ylim(.4, .8)
# Out:
# (0.4, 0.8)

# %%
files = ['TD3_max_pairwise_ground_truth_1___1.npy',
         'TD3_max_pairwise_ground_truth_2___1.npy',
         'TD3_max_pairwise_ground_truth_4___1.npy',
         'TD3_max_pairwise_ground_truth_8___1.npy',
         'TD3_max_pairwise_ground_truth_16___1.npy']

# %%
plots = [np.load(file) for file in files]
[plt.plot(p, label=f) for p,f in zip(plots, files)]
plt.legend(loc='lower right')
plt.xlabel('Thousands of steps')
plt.ylabel('Average Reward')
plt.title('Maximize Pairwise Distance Task')
plt.xlim(0, 1000)
plt.ylim(.4, .8)
# Out:
# (0.4, 0.8)

# %%
files = ['TD3_max_pairwise_None_1___1.npy',
         'TD3_max_pairwise_None_2___1.npy',
         'TD3_max_pairwise_None_4___1.npy',
         'TD3_max_pairwise_None_8___1.npy',
         'TD3_max_pairwise_None_16___1.npy']

# %%
plots = [np.load(file) for file in files]
[plt.plot(p, label=f) for p,f in zip(plots, files)]
plt.legend(loc='lower right')
plt.xlabel('Thousands of steps')
plt.ylabel('Average Reward')
plt.title('Maximize Pairwise Distance Task')
plt.xlim(0, 1000)
plt.ylim(.4, .8)
# Out:
# (0.4, 0.8)

# %%
files = ['TD3_min_pairwise_ground_truth_1___0.npy',
         'TD3_min_pairwise_ground_truth_2___0.npy',
         'TD3_min_pairwise_ground_truth_4___0.npy',
         'TD3_min_pairwise_ground_truth_8___0.npy',
         'TD3_min_pairwise_ground_truth_16___0.npy']

# %%
plots = [np.load(file) for file in files]
[plt.plot(p, label=f) for p,f in zip(plots, files)]
plt.legend(loc='lower right')
plt.xlabel('Thousands of steps')
plt.ylabel('Average Reward')
plt.title('Minimize Pairwise Distance Task')
plt.xlim(0, 1000)
plt.ylim(-.55, -.22)
# Out:
# (-0.55, -0.22)

# %%
files = ['TD3_min_pairwise_None_1___0.npy',
         'TD3_min_pairwise_None_2___0.npy',
         'TD3_min_pairwise_None_4___0.npy',
         'TD3_min_pairwise_None_8___0.npy',
         'TD3_min_pairwise_None_16___0.npy']

# %%
plots = [np.load(file) for file in files]
[plt.plot(p, label=f) for p,f in zip(plots, files)]
plt.legend()
plt.xlabel('Thousands of steps')
plt.ylabel('Average Reward')
plt.title('Minimize Pairwise Distance Task')
plt.xlim(0, 1000)
plt.ylim(-.55, -.22)
# Out:
# (-0.55, -0.22)

# %%
files = ['TD3_min_pairwise_ground_truth_1___1.npy',
         'TD3_min_pairwise_ground_truth_2___1.npy',
         'TD3_min_pairwise_ground_truth_4___1.npy',
         'TD3_min_pairwise_ground_truth_8___1.npy',
         'TD3_min_pairwise_ground_truth_16___1.npy']

# %%
plots = [np.load(file) for file in files]
[plt.plot(p, label=f) for p,f in zip(plots, files)]
plt.legend()
plt.xlabel('Thousands of steps')
plt.ylabel('Average Reward')
plt.title('Minimize Pairwise Distance Task')
plt.xlim(0, 1000)
plt.ylim(-.55, -.22)
# Out:
# (-0.55, -0.22)

# %%
files = ['TD3_min_pairwise_None_1___1.npy',
         'TD3_min_pairwise_None_2___1.npy',
         'TD3_min_pairwise_None_4___1.npy',
         'TD3_min_pairwise_None_8___1.npy',
         'TD3_min_pairwise_None_16___1.npy']

# %%
plots = [np.load(file) for file in files]
[plt.plot(p, label=f) for p,f in zip(plots, files)]
plt.legend()
plt.xlabel('Thousands of steps')
plt.ylabel('Average Reward')
plt.title('Minimize Pairwise Distance Task')
plt.xlim(0, 1000)
plt.ylim(-.55, -.22)
# Out:
# (-0.55, -0.22)
